# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
print(data[:10])
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
list(dictionary.items())[:10]
# Out:
# [('UNK', 0),
#  ('the', 1),
#  ('of', 2),
#  ('and', 3),
#  ('one', 4),
#  ('in', 5),
#  ('a', 6),
#  ('to', 7),
#  ('zero', 8),
#  ('nine', 9)]

# %%
list(reverse_dictionary.items())[:10]
# Out:
# [(0, 'UNK'),
#  (1, 'the'),
#  (2, 'of'),
#  (3, 'and'),
#  (4, 'one'),
#  (5, 'in'),
#  (6, 'a'),
#  (7, 'to'),
#  (8, 'zero'),
#  (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.018936
# Nearest to s: desert, skunk, brock, pub, slant, larnaca, intercontinental, concern,
# Nearest to only: tbs, koran, commuted, sibilant, bells, liechtenstein, aron, hungarians,
# Nearest to people: clam, claudius, unexpected, centripetal, eca, downey, metastability, v,
# Nearest to the: omens, kildall, pragmatism, therein, uriah, opec, clustering, braddock,
# Nearest to used: palpitations, jeremiah, woodcut, polygamous, surreptitiously, gott, dicaprio, danann,
# Nearest to and: trades, wenceslaus, theoretic, imitators, antipsychotics, gradual, obelix, nilpotent,
# Nearest to on: vci, replacing, fragmentation, tuscany, hertford, hashimoto, conceals, lagoons,
# Nearest to with: courts, bloom, stemmed, quinn, invoke, redirection, empties, exceptionally,
# Nearest to his: microclimates, helicopter, thwarted, leibniz, amortized, simpler, tamar, teenagers,
# Nearest to in: dilemma, reforms, xp, hopelessly, watches, swift, prosthetics, disillusioned,
# Nearest to it: baudelaire, gregor, emigrant, kasner, cook, rejoiced, poindexter, solves,
# Nearest to at: endless, avalokitesvara, incest, mchenry, where, acyclic, outskirts, integration,
# Nearest to all: leviathan, davidians, undercoat, penguins, estimate, brosnan, undertakings, remove,
# Nearest to they: eurosceptic, catnip, trojans, avalanches, ibsen, emphatically, beckham, duran,
# Nearest to some: jongg, fashioning, earnhardt, kip, hoard, controls, aether, preventive,
# Nearest to an: brazilians, browns, cutting, guile, biotech, hierarchies, rout, rowland,
# Average loss at step 2000: 4.364703
# Average loss at step 4000: 3.868916
# Average loss at step 6000: 3.796837
# Average loss at step 8000: 3.689782
# Average loss at step 10000: 3.616590
# Nearest to s: his, holst, mutualism, topics, causative, intercontinental, flattening, attlee,
# Nearest to only: musique, picirilli, bells, commuted, bleachers, families, conspiracy, proton,
# Nearest to people: daughters, substances, claudius, guericke, isfahan, haunt, centripetal, turmeric,
# Nearest to the: its, a, this, his, their, bleu, an, any,
# Nearest to used: surreptitiously, selkirk, known, palpitations, nanyang, tremendously, onlookers, called,
# Nearest to and: or, of, he, in, varnish, shrines, by, on,
# Nearest to on: in, during, with, resisting, classless, anselm, and, fragmentation,
# Nearest to with: by, on, heliopause, quinn, in, from, managerial, stemmed,
# Nearest to his: their, s, the, her, recur, fury, its, simpler,
# Nearest to in: on, of, at, from, with, for, by, and,
# Nearest to it: he, also, this, there, not, which, that, unsigned,
# Nearest to at: in, between, from, avalokitesvara, on, veracruz, martingale, kew,
# Nearest to all: hijacked, theatres, leviathan, quartic, infant, gash, orcus, purged,
# Nearest to they: he, not, we, there, breakthroughs, she, it, mal,
# Nearest to some: many, radians, amputees, rearden, earnhardt, chun, bmp, eerdmans,
# Nearest to an: browns, the, cutting, handlebar, petsamo, assurances, vulcan, polity,
# Average loss at step 12000: 3.603537
# Average loss at step 14000: 3.570924
# Average loss at step 16000: 3.411985
# Average loss at step 18000: 3.458944
# Average loss at step 20000: 3.537952
# Nearest to s: mutualism, holst, topics, quenched, protists, spirituals, immunity, and,
# Nearest to only: bleachers, picirilli, unsecured, burma, contended, pallium, sayyid, ripped,
# Nearest to people: substances, erdrich, daughters, claudius, prophetic, isfahan, themed, petitcodiac,
# Nearest to the: their, its, this, his, a, any, an, each,
# Nearest to used: surreptitiously, known, computation, called, found, tremendously, selkirk, seen,
# Nearest to and: or, but, which, in, pod, for, at, agonist,
# Nearest to on: in, upon, at, during, classless, resisting, sitar, constans,
# Nearest to with: in, stemmed, into, heliopause, for, between, amazon, by,
# Nearest to his: their, her, its, the, recur, fury, olin, kumar,
# Nearest to in: at, on, with, from, between, and, for, circumvent,
# Nearest to it: he, there, this, they, which, she, also, not,
# Nearest to at: in, from, on, avalokitesvara, martingale, and, between, emptiness,
# Nearest to all: many, hijacked, these, augsburg, several, mugwort, quartic, theatres,
# Nearest to they: he, we, there, it, who, she, you, not,
# Nearest to some: many, several, these, radians, other, amputees, types, ontological,
# Nearest to an: the, browns, wallets, attendant, vulcan, promised, brazilians, nylon,
# Average loss at step 22000: 3.496203
# Average loss at step 24000: 3.489559
# Average loss at step 26000: 3.481828
# Average loss at step 28000: 3.478771
# Average loss at step 30000: 3.503125
# Nearest to s: holst, his, photoshop, baptisms, quenched, mutualism, requests, whose,
# Nearest to only: bleachers, still, unsecured, picirilli, kossuth, transliterated, it, but,
# Nearest to people: children, those, erdrich, substances, prophetic, vote, others, claudius,
# Nearest to the: their, its, his, any, some, a, tapping, this,
# Nearest to used: known, surreptitiously, found, called, seen, shunting, written, belong,
# Nearest to and: or, but, however, in, boitano, entangled, aer, vocal,
# Nearest to on: upon, in, during, for, classless, through, resisting, at,
# Nearest to with: between, in, when, amazon, chakras, bilge, judeo, touristic,
# Nearest to his: her, their, its, the, s, our, recur, slovene,
# Nearest to in: at, during, on, from, between, with, of, under,
# Nearest to it: he, there, she, this, they, which, who, not,
# Nearest to at: in, avalokitesvara, martingale, when, huge, banisteriopsis, on, emptiness,
# Nearest to all: these, many, some, hijacked, several, brosnan, theatres, tosses,
# Nearest to they: we, there, he, you, it, who, not, she,
# Nearest to some: many, these, several, their, mixed, the, any, amputees,
# Nearest to an: petsamo, wallets, organizations, nylon, attendant, hierarchies, browns, promised,
# Average loss at step 32000: 3.504790
# Average loss at step 34000: 3.497082
# Average loss at step 36000: 3.455974
# Average loss at step 38000: 3.306451
# Average loss at step 40000: 3.423321
# Nearest to s: his, holst, tt, increments, casual, coronal, dnow, presumptive,
# Nearest to only: bleachers, it, unsecured, always, kossuth, even, still, indistinguishable,
# Nearest to people: children, members, those, others, bardeen, prophetic, surmised, lemmy,
# Nearest to the: their, a, this, its, any, his, each, or,
# Nearest to used: found, known, seen, referred, surreptitiously, available, written, possible,
# Nearest to and: or, but, in, UNK, nouakchott, agonist, of, for,
# Nearest to on: upon, during, at, in, hogshead, classless, resisting, supporting,
# Nearest to with: between, when, bilge, in, by, snake, stemmed, while,
# Nearest to his: her, their, its, s, the, telephus, recur, our,
# Nearest to in: of, from, at, during, on, until, to, and,
# Nearest to it: he, there, she, they, this, which, only, not,
# Nearest to at: in, on, banisteriopsis, fayette, between, during, martingale, astonishingly,
# Nearest to all: both, these, tsinghua, hijacked, vietnamese, incorporating, many, liege,
# Nearest to they: we, you, he, there, it, she, who, not,
# Nearest to some: many, several, these, any, mixed, certain, this, those,
# Nearest to an: hierarchies, wallets, petsamo, nylon, ghibellines, vulcan, opting, assurances,
# Average loss at step 42000: 3.439260
# Average loss at step 44000: 3.451424
# Average loss at step 46000: 3.446533
# Average loss at step 48000: 3.358258
# Average loss at step 50000: 3.378600
# Nearest to s: whose, holst, photoshop, mutualism, requests, serbian, conversely, quenched,
# Nearest to only: bleachers, always, sayyid, unsecured, qdos, rattle, still, saccharomyces,
# Nearest to people: children, members, bardeen, others, vote, erdrich, guericke, bolivian,
# Nearest to the: its, their, his, a, this, some, any, each,
# Nearest to used: known, seen, written, found, referred, presented, considered, available,
# Nearest to and: or, but, while, including, in, of, however, boitano,
# Nearest to on: upon, in, resisting, at, under, stumbled, indie, constans,
# Nearest to with: between, when, klan, while, stemmed, heliopause, wenzel, waterfowl,
# Nearest to his: their, her, its, the, our, him, acf, my,
# Nearest to in: within, during, on, stumbling, of, from, at, and,
# Nearest to it: he, there, she, they, this, engraver, ratifying, now,
# Nearest to at: during, deficiency, in, on, between, astonishingly, banisteriopsis, avalokitesvara,
# Nearest to all: both, these, attendances, theatres, unomig, any, tsinghua, many,
# Nearest to they: we, he, there, you, she, it, who, not,
# Nearest to some: many, several, these, most, the, mixed, this, both,
# Nearest to an: wallets, assurances, vulcan, hierarchies, cutting, petsamo, attendant, noon,
# Average loss at step 52000: 3.437961
# Average loss at step 54000: 3.425781
# Average loss at step 56000: 3.440016
# Average loss at step 58000: 3.397973
# Average loss at step 60000: 3.398278
# Nearest to s: holst, whose, arthur, quenched, paracompact, apec, gears, conversely,
# Nearest to only: bleachers, always, still, unsecured, christa, first, but, atm,
# Nearest to people: members, children, others, bardeen, erdrich, prophetic, those, players,
# Nearest to the: their, a, its, some, polygamy, his, each, any,
# Nearest to used: known, seen, written, referred, found, published, considered, described,
# Nearest to and: or, but, than, including, although, nouakchott, in, consigned,
# Nearest to on: upon, resisting, through, sitar, in, under, cordilleras, conceals,
# Nearest to with: between, when, in, stemmed, pares, bureaucracies, amazon, within,
# Nearest to his: her, their, its, my, our, the, recur, acf,
# Nearest to in: within, during, of, at, between, with, since, for,
# Nearest to it: he, she, there, this, which, they, now, tremendous,
# Nearest to at: in, banisteriopsis, during, martingale, avalokitesvara, near, astonishingly, onto,
# Nearest to all: both, these, those, any, many, theism, some, cordon,
# Nearest to they: we, there, you, he, she, it, not, who,
# Nearest to some: many, several, these, most, this, any, mixed, the,
# Nearest to an: hierarchies, wallets, assurances, nylon, breasted, cutting, petsamo, generating,
# Average loss at step 62000: 3.246702
# Average loss at step 64000: 3.254903
# Average loss at step 66000: 3.405581
# Average loss at step 68000: 3.397605
# Average loss at step 70000: 3.358371
# Nearest to s: whose, holst, organizers, werth, goguryeo, photoshop, elba, the,
# Nearest to only: bleachers, always, christa, still, saccharomyces, never, sayyid, unsecured,
# Nearest to people: children, members, others, bardeen, players, women, scholars, prophetic,
# Nearest to the: their, its, a, any, polygamy, your, this, his,
# Nearest to used: seen, known, written, found, referred, described, considered, published,
# Nearest to and: or, but, autodidacts, like, while, pod, than, including,
# Nearest to on: upon, through, in, within, resisting, around, urgent, under,
# Nearest to with: between, stemmed, helper, without, when, among, munro, by,
# Nearest to his: her, their, its, my, our, the, your, recur,
# Nearest to in: within, on, during, for, until, through, from, between,
# Nearest to it: he, she, there, this, they, we, which, god,
# Nearest to at: avalokitesvara, martingale, during, in, for, banisteriopsis, ku, rta,
# Nearest to all: both, many, these, any, some, those, each, every,
# Nearest to they: we, he, there, you, it, she, who, i,
# Nearest to some: many, several, these, most, both, all, this, their,
# Nearest to an: nylon, wallets, the, hierarchies, breasted, brazilians, attendant, assurances,
# Average loss at step 72000: 3.378356
# Average loss at step 74000: 3.350960
# Average loss at step 76000: 3.319269
# Average loss at step 78000: 3.352232
# Average loss at step 80000: 3.374812
# Nearest to s: isbn, francium, goguryeo, photoshop, spirituals, whose, ulfilas, mutualism,
# Nearest to only: always, bleachers, next, sticks, saccharomyces, sayyid, transliterated, reg,
# Nearest to people: children, members, men, others, women, erdrich, bardeen, someone,
# Nearest to the: this, its, their, polygamy, a, his, any, each,
# Nearest to used: known, referred, seen, written, described, found, available, defined,
# Nearest to and: or, but, while, including, elaborately, physiologist, totalling, turismo,
# Nearest to on: upon, in, through, during, resisting, hogshead, at, within,
# Nearest to with: between, genji, in, when, stemmed, without, munro, by,
# Nearest to his: her, their, its, my, our, your, the, kaddish,
# Nearest to in: within, during, until, on, at, cj, since, from,
# Nearest to it: he, she, there, this, they, we, never, activation,
# Nearest to at: in, banisteriopsis, martingale, on, fitzroy, during, via, avalokitesvara,
# Nearest to all: both, any, every, many, some, each, these, various,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to some: many, several, these, most, both, various, all, numerous,
# Nearest to an: wallets, assurances, hierarchies, breasted, attendant, everywhere, noon, carmilla,
# Average loss at step 82000: 3.407352
# Average loss at step 84000: 3.410400
# Average loss at step 86000: 3.387047
# Average loss at step 88000: 3.355432
# Average loss at step 90000: 3.368651
# Nearest to s: whose, holst, isbn, spirituals, arthur, our, inductees, presumptive,
# Nearest to only: always, reg, bleachers, atm, next, even, every, qdos,
# Nearest to people: children, men, women, members, players, erdrich, students, someone,
# Nearest to the: its, their, his, this, a, each, any, whose,
# Nearest to used: known, referred, seen, described, designed, given, written, called,
# Nearest to and: or, but, while, autodidacts, entangled, including, nouakchott, however,
# Nearest to on: upon, under, through, conceals, against, resisting, at, around,
# Nearest to with: between, genji, without, when, in, quinn, within, pares,
# Nearest to his: her, their, its, my, our, your, the, kaddish,
# Nearest to in: within, during, until, of, around, from, at, with,
# Nearest to it: he, she, there, this, they, soon, we, which,
# Nearest to at: during, near, martingale, banisteriopsis, until, in, uninhabitable, fitzroy,
# Nearest to all: both, every, some, several, many, these, any, each,
# Nearest to they: we, he, there, she, you, it, these, but,
# Nearest to some: many, several, these, most, all, any, this, those,
# Nearest to an: assurances, wallets, noon, attendant, breasted, hierarchies, centralised, nylon,
# Average loss at step 92000: 3.397286
# Average loss at step 94000: 3.255018
# Average loss at step 96000: 3.357059
# Average loss at step 98000: 3.244417
# Average loss at step 100000: 3.360359
# Nearest to s: whose, quenched, holst, photoshop, fingering, inductees, conversely, attlee,
# Nearest to only: christa, always, within, never, next, latter, qdos, rattle,
# Nearest to people: children, men, women, players, members, someone, others, fans,
# Nearest to the: its, your, their, a, his, formalize, our, this,
# Nearest to used: referred, seen, known, given, designed, considered, found, allowed,
# Nearest to and: or, but, although, while, however, when, including, hillsdale,
# Nearest to on: upon, within, at, hogshead, in, under, through, alarc,
# Nearest to with: between, when, bilge, during, including, within, helper, using,
# Nearest to his: her, their, my, our, its, your, the, consultative,
# Nearest to in: within, during, until, from, under, near, on, throughout,
# Nearest to it: he, she, there, this, they, soon, not, never,
# Nearest to at: during, on, near, banisteriopsis, martingale, in, stereotypically, ghola,
# Nearest to all: every, these, various, many, several, some, both, any,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to some: many, several, these, numerous, any, various, all, their,
# Nearest to an: nylon, assurances, noon, wallets, everywhere, deshima, breasted, hierarchies,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(
        weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
        labels=train_labels, num_sampled=num_sampled, 
        num_classes=vocabulary_size))
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.814419
# Nearest to system: paul, voltage, outsold, schumpeter, notting, hlich, acyclic, muller,
# Nearest to have: absolute, kalimantan, savannas, personal, atp, geschichte, consistory, kia,
# Nearest to most: conjunctive, abolitionist, nigerian, pennsylvania, particles, noticing, finals, eschew,
# Nearest to had: bevel, aesop, durr, dustin, zappa, proximal, profitability, nutty,
# Nearest to people: unfortunate, avoidance, tattooed, amerindian, viewpoint, whitbread, concealing, meanwhile,
# Nearest to nine: process, abingdon, fostered, joule, angry, bushman, insert, lowered,
# Nearest to all: hegelians, gunnery, milliardo, lcc, yzerman, circuit, alzheimer, postgresql,
# Nearest to who: underscore, traction, dooley, indivisible, beetles, subservient, wish, talleyrand,
# Nearest to five: xhtml, wendell, amber, disease, annihilated, lauded, rudd, boer,
# Nearest to these: cadillac, commons, adnan, nonce, catwoman, jokes, ganglia, incursions,
# Nearest to d: aleutian, conclude, jamaica, diverse, mineralogical, littoral, dams, dieter,
# Nearest to was: pipe, erstwhile, obverse, expeditionary, academies, supplementary, occupied, angelo,
# Nearest to his: cartagena, dacko, threw, implicit, hsu, gluons, polynomial, inflicted,
# Nearest to four: bacilli, encounters, microorganisms, dddddd, choke, motilal, attainable, mears,
# Nearest to is: trillion, xvi, ts, jonathan, blank, cherokees, endomorphisms, charters,
# Nearest to or: mysteries, mudslides, sandy, ramparts, hopefully, mika, baseman, bormann,
# Average loss at step 2000: 4.474823
# Average loss at step 4000: 3.871881
# Average loss at step 6000: 3.771505
# Average loss at step 8000: 3.612580
# Average loss at step 10000: 3.549946
# Nearest to system: anonymously, workgroups, compacted, patel, miserably, mangaverse, subhas, reichsf,
# Nearest to have: has, had, be, raise, were, hom, hanseatic, coleridge,
# Nearest to most: ogg, many, more, some, azores, ports, first, caesars,
# Nearest to had: has, have, was, having, instruments, morphological, became, were,
# Nearest to people: avoidance, reneged, imbolc, reece, ce, amerindian, overlook, riff,
# Nearest to nine: eight, seven, six, five, four, zero, stallions, three,
# Nearest to all: many, some, diver, steeped, hotels, kashrut, reduplication, hyperbola,
# Nearest to who: he, katzenjammer, by, ri, she, afterwards, motorcycle, they,
# Nearest to five: four, three, six, seven, eight, nine, multicellular, two,
# Nearest to these: many, some, other, overdoses, they, eck, pairing, several,
# Nearest to d: metastable, colonize, orbital, ku, unready, vince, amputees, leet,
# Nearest to was: is, became, were, had, are, has, waltz, icsu,
# Nearest to his: her, their, its, the, stromata, schismatic, opportunities, herod,
# Nearest to four: five, six, seven, three, eight, nine, two, marcian,
# Nearest to is: was, are, has, alp, were, gunfire, became, gentoo,
# Nearest to or: and, gab, than, transformation, but, mummified, kernels, consequential,
# Average loss at step 12000: 3.537045
# Average loss at step 14000: 3.517015
# Average loss at step 16000: 3.366470
# Average loss at step 18000: 3.155369
# Average loss at step 20000: 3.212259
# Nearest to system: systems, anonymously, subhas, objective, patel, finances, pretty, possessor,
# Nearest to have: has, had, having, produce, include, raise, be, kalimantan,
# Nearest to most: more, many, azores, because, grote, connectedness, ogg, some,
# Nearest to had: has, have, having, were, was, saw, melito, would,
# Nearest to people: men, tribes, bonus, hydra, valuation, gareth, unalaska, brain,
# Nearest to nine: eight, seven, six, five, four, zero, three, may,
# Nearest to all: various, some, both, bouvines, many, magellanic, trist, owners,
# Nearest to who: concatenation, which, by, that, she, sculpture, overheard, able,
# Nearest to five: eight, four, seven, six, three, nine, zero, two,
# Nearest to these: many, some, other, several, various, pairing, eck, different,
# Nearest to d: b, conspiring, dredging, intentionality, nomination, logicians, bacilli, interpreting,
# Nearest to was: is, were, became, are, had, being, includes, has,
# Nearest to his: her, their, its, the, your, opportunities, s, my,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to is: was, are, were, became, has, includes, be, being,
# Nearest to or: and, than, while, carolus, but, ilmarinen, surgeons, colloquially,
# Average loss at step 22000: 3.371394
# Average loss at step 24000: 3.222393
# Average loss at step 26000: 3.256226
# Average loss at step 28000: 3.305141
# Average loss at step 30000: 3.196122
# Nearest to system: systems, anonymously, scale, microscope, activity, sketched, burgundian, plan,
# Nearest to have: had, has, having, include, produce, are, require, were,
# Nearest to most: many, more, less, very, particularly, azores, cocos, some,
# Nearest to had: has, have, having, was, saw, were, with, makes,
# Nearest to people: men, countries, those, tribes, them, bonus, others, women,
# Nearest to nine: eight, seven, six, four, zero, late, five, august,
# Nearest to all: many, some, various, eagerly, mjs, symbols, airs, cautions,
# Nearest to who: that, which, he, institut, ophile, overheard, antoinette, asquith,
# Nearest to five: four, six, seven, three, zero, eight, two, nine,
# Nearest to these: various, certain, different, some, other, several, those, their,
# Nearest to d: b, frac, ivoire, factor, convent, ballerina, individualist, downstream,
# Nearest to was: is, were, became, are, includes, had, has, becomes,
# Nearest to his: her, their, its, s, your, my, the, novices,
# Nearest to four: seven, six, three, five, eight, nine, two, zero,
# Nearest to is: was, are, has, includes, makes, were, corsair, cumulative,
# Nearest to or: and, than, hollingworth, trousers, while, consulates, ncc, kawasaki,
# Average loss at step 32000: 3.164609
# Average loss at step 34000: 3.150074
# Average loss at step 36000: 3.061672
# Average loss at step 38000: 3.087967
# Average loss at step 40000: 3.100659
# Nearest to system: systems, anonymously, plan, typology, triumphantly, activity, device, ssbauer,
# Nearest to have: has, had, having, produce, be, include, marries, badminton,
# Nearest to most: more, many, some, less, particularly, grote, azores, landlord,
# Nearest to had: has, have, having, was, saw, were, dd, could,
# Nearest to people: men, those, students, members, scientists, tribes, commentators, players,
# Nearest to nine: seven, eight, six, five, three, four, zero, two,
# Nearest to all: various, several, many, some, every, certain, tegucigalpa, yesterday,
# Nearest to who: which, young, whose, he, simmons, that, whom, overheard,
# Nearest to five: four, six, eight, three, zero, seven, two, nine,
# Nearest to these: various, certain, both, several, other, which, the, their,
# Nearest to d: b, dijkstra, radiative, singer, leyland, declines, wilkes, apollo,
# Nearest to was: is, were, became, being, are, had, becomes, be,
# Nearest to his: her, their, its, my, the, your, s, whose,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to is: was, became, are, has, becomes, makes, includes, does,
# Nearest to or: and, than, qam, hollingworth, downloading, while, like, blanking,
# Average loss at step 42000: 3.104980
# Average loss at step 44000: 3.135280
# Average loss at step 46000: 3.092724
# Average loss at step 48000: 2.972996
# Average loss at step 50000: 3.099343
# Nearest to system: systems, plan, device, ballpark, project, ssbauer, stringent, mustang,
# Nearest to have: has, had, having, include, require, be, marries, produce,
# Nearest to most: more, some, particularly, especially, very, less, many, highly,
# Nearest to had: has, have, having, was, saw, gave, were, could,
# Nearest to people: men, scientists, students, inhabitants, players, scholars, those, commentators,
# Nearest to nine: eight, late, seven, six, four, mid, palsy, september,
# Nearest to all: many, every, some, several, both, each, various, certain,
# Nearest to who: he, and, she, alfredo, young, generally, by, which,
# Nearest to five: three, four, zero, six, eight, two, seven, ceasing,
# Nearest to these: various, certain, some, many, several, number, ignacio, other,
# Nearest to d: b, choi, cemac, downstream, tale, domine, ammonite, selassie,
# Nearest to was: is, were, became, had, becomes, are, does, makes,
# Nearest to his: their, her, its, the, your, s, our, whose,
# Nearest to four: five, two, three, six, eight, seven, zero, nine,
# Nearest to is: was, are, became, becomes, makes, has, includes, remains,
# Nearest to or: than, and, berzelius, electrically, ebony, toward, himachal, mueller,
# Average loss at step 52000: 3.064726
# Average loss at step 54000: 3.063192
# Average loss at step 56000: 3.081704
# Average loss at step 58000: 3.012173
# Average loss at step 60000: 2.830729
# Nearest to system: systems, activity, lingerie, device, ballpark, project, process, anonymously,
# Nearest to have: had, has, having, are, produce, include, were, require,
# Nearest to most: many, some, more, especially, particularly, less, feng, none,
# Nearest to had: has, have, having, was, gave, could, saw, were,
# Nearest to people: men, members, soldiers, inhabitants, observers, women, children, those,
# Nearest to nine: eight, seven, five, four, six, late, zero, september,
# Nearest to all: many, every, any, those, certain, some, various, both,
# Nearest to who: whom, which, young, stadtbahn, bbses, alfredo, lamia, he,
# Nearest to five: six, eight, four, seven, three, zero, nine, two,
# Nearest to these: some, various, numerous, many, certain, different, several, which,
# Nearest to d: b, expound, nicolau, harp, r, selassie, homemade, combs,
# Nearest to was: is, were, became, had, has, becomes, are, includes,
# Nearest to his: their, her, its, my, our, the, your, whose,
# Nearest to four: six, three, five, eight, seven, nine, zero, two,
# Nearest to is: was, becomes, includes, makes, are, became, remains, contains,
# Nearest to or: and, vs, gab, than, superconductor, but, leith, irrevocably,
# Average loss at step 62000: 3.019302
# Average loss at step 64000: 3.010117
# Average loss at step 66000: 3.012445
# Average loss at step 68000: 3.015791
# Average loss at step 70000: 3.062937
# Nearest to system: systems, activity, process, anonymously, ballpark, name, targ, device,
# Nearest to have: has, had, having, require, contain, provide, produce, allow,
# Nearest to most: more, less, best, many, particularly, first, especially, achille,
# Nearest to had: has, have, having, was, gave, could, saw, contains,
# Nearest to people: men, students, inhabitants, members, those, practitioners, women, soldiers,
# Nearest to nine: eight, seven, six, five, september, late, th, two,
# Nearest to all: various, many, some, every, those, any, certain, several,
# Nearest to who: he, whom, nynorsk, toccata, asquith, popularizer, wynne, vinegar,
# Nearest to five: seven, eight, six, three, four, zero, nine, two,
# Nearest to these: various, several, which, whose, specific, special, this, twigs,
# Nearest to d: b, expound, facsimile, domine, harp, leyland, slurred, l,
# Nearest to was: is, were, became, becomes, had, are, remains, includes,
# Nearest to his: her, their, its, my, our, your, s, whose,
# Nearest to four: three, five, six, seven, eight, zero, two, apostle,
# Nearest to is: was, becomes, are, includes, makes, contains, remains, means,
# Nearest to or: and, befell, spires, than, berzelius, tewahedo, hollingworth, etc,
# Average loss at step 72000: 3.001797
# Average loss at step 74000: 3.019977
# Average loss at step 76000: 2.931245
# Average loss at step 78000: 2.928187
# Average loss at step 80000: 2.979029
# Nearest to system: systems, approach, project, process, device, plan, application, method,
# Nearest to have: had, has, having, produce, contain, require, allow, include,
# Nearest to most: many, less, more, some, particularly, especially, daime, highly,
# Nearest to had: has, have, having, gave, ve, wrote, were, saw,
# Nearest to people: men, students, someone, players, workers, jews, scientists, individuals,
# Nearest to nine: eight, seven, six, four, th, five, zero, senatorial,
# Nearest to all: various, several, many, these, every, those, multiple, certain,
# Nearest to who: young, whom, he, concatenation, stadtbahn, cements, which, already,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to these: various, several, certain, numerous, jeddah, specific, all, other,
# Nearest to d: b, expound, groningen, alleles, osh, facsimile, analyte, geospatial,
# Nearest to was: is, were, became, being, becomes, remains, are, includes,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to four: five, seven, three, eight, six, nine, zero, mw,
# Nearest to is: was, are, remains, makes, includes, became, were, becomes,
# Nearest to or: and, than, towards, versus, toward, superconductor, vs, antoninianus,
# Average loss at step 82000: 2.972699
# Average loss at step 84000: 2.811598
# Average loss at step 86000: 2.919263
# Average loss at step 88000: 2.944906
# Average loss at step 90000: 2.925218
# Nearest to system: systems, process, program, device, script, element, activity, network,
# Nearest to have: has, had, having, require, contain, include, allow, produce,
# Nearest to most: especially, many, less, particularly, more, highly, all, best,
# Nearest to had: has, have, having, gave, saw, requires, was, could,
# Nearest to people: men, those, children, scientists, players, someone, individuals, speakers,
# Nearest to nine: eight, seven, six, five, three, th, september, four,
# Nearest to all: many, various, both, several, some, none, numerous, certain,
# Nearest to who: he, whose, whom, she, dukakis, overheard, that, carnivora,
# Nearest to five: seven, six, three, four, eight, zero, two, nine,
# Nearest to these: numerous, various, several, jeddah, some, certain, additional, those,
# Nearest to d: b, c, expound, rables, cyclopedia, groningen, weldon, frac,
# Nearest to was: is, were, becomes, became, remains, are, being, had,
# Nearest to his: her, their, its, your, my, our, the, whose,
# Nearest to four: three, seven, five, six, eight, two, zero, nine,
# Nearest to is: was, becomes, are, remains, includes, provides, involves, makes,
# Nearest to or: and, than, gdynia, marcellus, superconductor, nichols, cle, interception,
# Average loss at step 92000: 2.824748
# Average loss at step 94000: 2.832562
# Average loss at step 96000: 2.874061
# Average loss at step 98000: 2.914775
# Average loss at step 100000: 2.831405
# Nearest to system: systems, program, process, activity, ssbauer, project, function, qe,
# Nearest to have: has, had, having, contain, require, include, provide, allow,
# Nearest to most: many, some, more, particularly, none, safed, especially, less,
# Nearest to had: has, have, having, saw, was, contains, requires, gave,
# Nearest to people: men, players, individuals, residents, citizens, someone, persons, women,
# Nearest to nine: eight, seven, six, five, late, pastures, th, four,
# Nearest to all: many, both, every, various, some, certain, numerous, seti,
# Nearest to who: which, he, she, whom, simmons, toponyms, trot, holocaust,
# Nearest to five: six, three, four, eight, seven, zero, nine, two,
# Nearest to these: those, whose, special, different, certain, some, various, they,
# Nearest to d: b, groningen, rables, varepsilon, monitored, ivoire, silicate, post,
# Nearest to was: is, were, becomes, remains, became, had, are, has,
# Nearest to his: their, her, its, my, your, our, the, whose,
# Nearest to four: three, five, six, seven, eight, two, zero, nine,
# Nearest to is: was, are, remains, becomes, became, includes, provides, makes,
# Nearest to or: and, including, etc, without, but, spires, ebony, than,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
